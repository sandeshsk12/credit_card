# %%
import pandas as pd
import numpy as np
df=pd.read_csv('training_file_from_db/training_file.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
features=data.drop(['default_payment_next_month','ID'],axis=1)
target=data['default_payment_next_month']

# %%
X_train,X_test,y_train,y_test = train_test_split(features,target,test_size=0.2,random_state=10)

# %%
import pickle
with open('models/trained_model','rb') as f:
	mp=pickle.load(f)

# %%
y_pred=mp.predict(X_test)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
mp=model

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC


predictions = mp.predict(X_test)
cm = confusion_matrix(y_test, predictions, labels=mp.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=mp.classes_)
disp.plot()

plt.show()

# %%
l=len(df[df['default_payment_next_month']==1])
a1=df[df['default_payment_next_month']==1]

# %%
b0=df[df['default_payment_next_month']==0].iloc[:l,:]

# %%
data=pd.concat((a1,b0),axis=0)

# %%
data
# Out:
#         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0        1      20000    2          2         1   24      2      2     -1
# 1        2     120000    2          2         2   26     -1      2      0
# 13      14      70000    1          2         2   30      1      2      2
# 16      17      20000    1          1         2   24      0      0      2
# 21      22     120000    2          2         1   39     -1     -1     -1
# ...    ...        ...  ...        ...       ...  ...    ...    ...    ...
# 8551  8552     100000    2          3         1   28     -2     -2     -2
# 8552  8553      50000    2          3         1   30     -2     -2     -2
# 8554  8555     270000    1          2         1   49     -1     -1      0
# 8555  8556     260000    1          1         2   38      0     -1     -1
# 8556  8557     250000    2          2         2   32      0      0      0
#
#       PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...
